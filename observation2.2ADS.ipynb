# %% [markdown]
# # **Merge sort**

# %%
def mergeSort(arr):
    if len(arr) > 1:
        mid = len(arr)//2
        sub_array1 = arr[:mid]
        sub_array2 = arr[mid:]
        mergeSort(sub_array1)
        mergeSort(sub_array2)
        i = j = k = 0

        while i < len(sub_array1) and j < len(sub_array2):
            if sub_array1[i] < sub_array2[j]:
                arr[k] = sub_array1[i]
                i += 1
            else:
                arr[k] = sub_array2[j]
                j += 1
            k += 1
        while i < len(sub_array1):
            arr[k] = sub_array1[i]
            i += 1
            k += 1

        while j < len(sub_array2):
            arr[k] = sub_array2[j]
            j += 1
            k += 1

arr = [10, 9, 20, 4, 6, 2]
mergeSort(arr)
print(arr)
# Out:
# [2, 4, 6, 9, 10, 20]

# %% [markdown]
# # **Heap Sort**

# %%
def heapify(arr, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2
    if l < n and arr[i] < arr[l]:
        largest = l
    if r < n and arr[largest] < arr[r]:
        largest = r
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)
def heapSort(arr):
    n = len(arr)
    for i in range(n//2, -1, -1):
        heapify(arr, n, i)

    for i in range(n-1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)
arr = [1, 12, 9, 5, 6, -4]
heapSort(arr)
n = len(arr)
print("Sorted array is")
for i in range(n):
    print("%d " % arr[i], end='')
# Out:
# Sorted array is
# -4 1 5 6 9 12

# %% [markdown]
# **U do like import the heap element and using the data must sort**

# %%
import heapq
def heap_sort(arr):
	heapq.heapify(arr)
	result = []
	while arr:
		result.append(heapq.heappop(arr))
	return result
arr = [0.001,-20,-1,-30,-0.5]
print("Input Array: ", arr)
print("Sorted Array: ", heap_sort(arr))
# Out:
# Input Array:  [0.001, -20, -1, -30, -0.5]
# Sorted Array:  [-30, -20, -1, -0.5, 0.001]
