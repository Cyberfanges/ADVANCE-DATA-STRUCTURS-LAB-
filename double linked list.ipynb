# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        if self.head is not None:
            self.head.prev = new_node
        self.head = new_node
        new_node.prev = None

    def insert_at_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
        new_node.prev = last

    def delete_node(self, key):
        current = self.head
        while current:
            if current.data == key:
                if current.prev:
                    current.prev.next = current.next
                if current.next:
                    current.next.prev = current.prev
                if current == self.head:
                    self.head = current.next
                current = None
                return
            current = current.next

    def update_node(self, old_value, new_value):
        current = self.head
        while current:
            if current.data == old_value:
                current.data = new_value
                return
            current = current.next
        print(f"Value {old_value} not found in the list.")

    def print_list(self):
        current = self.head
        while current:
            print(current.data, end=" <-> ")
            current = current.next
        print("None")
if __name__ == "__main__":
    dll = DoublyLinkedList()
    while True:
        print("\n1. Insert at beginning")
        print("2. Insert at end")
        print("3. Delete a node")
        print("4. Update a node")
        print("5. Print list")
        print("6. Exit")
        choice = input("Choose an option (1-6): ")
        if choice == '1':
            data = int(input("Enter the value to insert at the beginning: "))
            dll.insert_at_beginning(data)
        elif choice == '2':
            data = int(input("Enter the value to insert at the end: "))
            dll.insert_at_end(data)
        elif choice == '3':
            key = int(input("Enter the value to delete: "))
            dll.delete_node(key)
        elif choice == '4':
            old_value = int(input("Enter the value to update: "))
            new_value = int(input("Enter the new value: "))
            dll.update_node(old_value, new_value)
        elif choice == '5':
            dll.print_list()
        elif choice == '6':
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please choose again.")
# Out:
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 1
# Enter the value to insert at the beginning: 5
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 1
# Enter the value to insert at the beginning: 2
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 1
# Enter the value to insert at the beginning: 67
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 1
# Enter the value to insert at the beginning: 34
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 5
# 34 <-> 67 <-> 2 <-> 5 <-> None
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 2
# Enter the value to insert at the end: 555
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 5
# 34 <-> 67 <-> 2 <-> 5 <-> 555 <-> None
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 3
# Enter the value to delete: 2
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 5
# 34 <-> 67 <-> 5 <-> 555 <-> None
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 4
# Enter the value to update: 2
# Enter the new value: 5
# Value 2 not found in the list.
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 4
# Enter the value to update: 555
# Enter the new value: 444
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 5
# 34 <-> 67 <-> 5 <-> 444 <-> None
#
# 1. Insert at beginning
# 2. Insert at end
# 3. Delete a node
# 4. Update a node
# 5. Print list
# 6. Exit
# Choose an option (1-6): 6
# Exiting...
